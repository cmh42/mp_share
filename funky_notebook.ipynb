# %% [markdown]
# # Shared Notebook for Testing

# %%
def funky_rabbit(number): 
    for _ in range(number):
        print("Funky Rabbit")
    return None

# %%
funky_rabbit(8)
# Out:
# Funky Rabbit
# Funky Rabbit
# Funky Rabbit
# Funky Rabbit
# Funky Rabbit
# Funky Rabbit
# Funky Rabbit
# Funky Rabbit
